# %% [markdown]
# <a href="https://colab.research.google.com/github/sarthaksharma-github/NSE-Moving-Average-Dashboard/blob/main/Project_1_(Stock_Dashboard).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt


data = yf.download("TCS.NS","2024-04-01","2026-04-01")

close = data["Close"]
data["MA20"] = data["Close"].rolling(window=20).mean()
data["MA50"] = data["Close"].rolling(window=50).mean()

plt.plot(data.index, data["Close"], label = "TCS Close Price")
plt.plot(data.index, data["MA20"], label = "MA20")
plt.plot(data.index, data["MA50"], label = "MA50")
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_2619/2142237774.py:6: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download("TCS.NS","2024-04-01","2026-04-01")
# [*********************100%***********************]  1 of 1 completed
